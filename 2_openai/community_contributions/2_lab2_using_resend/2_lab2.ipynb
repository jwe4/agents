# %% [markdown]
# ## Week 2 Day 2
#
# Our first Agentic Framework project!!
#
# Prepare yourself for something ridiculously easy.
#
# We're going to build a simple Agent system for generating cold sales outreach emails:
# 1. Agent workflow
# 2. Use of tools to call functions
# 3. Agent collaboration via Tools and Handoffs

# %% [markdown]
# ## Before we start - some setup:
#
#
# Please visit Sendgrid at: https://sendgrid.com/
#
# (Sendgrid is a Twilio company for sending emails.)
#
# If SendGrid gives you problems, see the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# Please set up an account - it's free! (at least, for me, right now).
#
# Once you've created an account, click on:
#
# Settings (left sidebar) >> API Keys >> Create API Key (button on top right)
#
# Copy the key to the clipboard, then add a new line to your .env file:
#
# `SENDGRID_API_KEY=xxxx`
#
# And also, within SendGrid, go to:
#
# Settings (left sidebar) >> Sender Authentication >> "Verify a Single Sender"
# and verify that your own email address is a real email address, so that SendGrid can send emails for you.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import requests
import os
import asyncio
import resend

# %%
load_dotenv(override=True)
# Out:
# True

# %%
email = os.getenv("GMAIL_TO")
print(email)
# Out:
# jeweaver@gmail.com

# %%
RESEND_API_KEY = os.getenv("RESEND_API_KEY")

# %% [markdown]
# ## Step 1: Agent workflow

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini"
)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# Subject: Streamline Your SOC 2 Compliance Process
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. I'm [Your Name] from ComplAI, and I'm reaching out to introduce how our innovative SaaS tool can transform your SOC 2 compliance process.
#
# Ensuring compliance can be a complex and time-consuming challenge. Our AI-powered platform simplifies the entire process, providing you with real-time insights and automating the documentation required for audits. By using ComplAI, organizations typically reduce compliance preparation time by up to 50%, allowing teams to focus on what they do best.
#
# We would love to show you how our solution can specifically address your compliance needs and improve your audit readiness. Are you available for a brief 20-minute call next week to discuss this further?
#
# Looking forward to the possibility of working together.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your LinkedIn Profile or Company Website]

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# Subject: Elevate Your SOC 2 Compliance Efforts with ComplAI
#
# Hi [Recipient's Name],
#
# I hope this message finds you well.
#
# Navigating SOC 2 compliance can be a daunting task, especially with the complexities of maintaining standards and preparing for audits. At ComplAI, we empower companies like yours with an AI-driven SaaS tool designed specifically to streamline the compliance process.
#
# Our solution offers:
#
# - **Automated Documentation**: Save time with smart templates and document generation tailored to your specific needs.
# - **Real-Time Compliance Monitoring**: Stay ahead with continuous monitoring and alerts on compliance gaps.
# - **Insightful Reporting**: Easily generate reports for internal use and external audits, ensuring transparency and preparedness.
#
# As organizations increasingly prioritize data security, having a robust compliance strategy is not just advantageous; it's essential. I'd welcome the opportunity to discuss how ComplAI can simplify your compliance efforts and enhance your audit readiness.
#
# Are you open to a brief conversation next week?
#
# Best regards,
# [Your Name]
# [Your Title]
# ComplAI
# [Your Phone Number]
# [Your LinkedIn Profile]
# [Your Company Website]
#
# ---
# Feel free to adjust any details as needed to better fit your style or specific recipient!
#
#
# Subject: 📊 Let’s Make SOC 2 Compliance Less Scary (and More Fun!)
#
# Hi [Recipient's Name],
#
# Hope this email finds you nonchalantly riding the wave of compliance bliss! I know the thought of SOC 2 compliance might make you feel like you’ve just accidentally clicked “reply all” on an office-wide email—suddenly terrifying, and with no way to escape!
#
# That’s where ComplAI struts in like the hero of your compliance comic. 🌟 We’re not just another SaaS tool; we’re your trusty sidekick, armed with AI superpowers to tackle audits and ensure compliance without the usual stress. Think of us as the fairy godmother for your data security needs, minus the pumpkin carriage.
#
# Here are a few magic tricks we can perform:
#
# 1. **Automated Readiness** – Forget endless spreadsheets. Our tool prepares you for audits faster than you can say “Let me check my calendar!” 📅
#
# 2. **Real-time Monitoring** – Think of it as having a security guard that never takes a coffee break. ☕
#
# 3. **Stress-Free Reporting** – Because who needs more headaches in their life?
#
# Interested in a quick demo? I promise, it'll be way more fun than a root canal! Let me know a time that works for you, or just reply with a funny GIF. I’ll take either! 😄
#
# Cheers to compliance without the chaos,
#
# [Your Name]
# [Your Position]
# ComplAI
# [Your Contact Information]
# P.S. Did I mention we also have a solid collection of memes about audits? We might just send a few your way! 🎉
#
#
# Subject: Simplify Your SOC 2 Compliance with AI
#
# Hi [Recipient's Name],
#
# I hope this finds you well! I’m reaching out to introduce ComplAI, our AI-powered tool designed to streamline SOC 2 compliance and simplify audit preparations.
#
# Our platform automates documentation, monitors risks, and ensures you stay compliant without the usual headaches. Companies like [Example Client] have seen significant reductions in time and costs related to their compliance processes.
#
# Would you be open to a brief call this week to see how we can help your organization?
#
# Best,
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your LinkedIn URL]

# %%
sales_picker = Agent(
    name="sales_picker",
    instructions="You pick the best cold sales email from the given options. \
Imagine you are a customer and pick the one you are most likely to respond to. \
Do not give an explanation; reply with the selected email only.",
    model="gpt-4o-mini"
)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

    outputs = [result.final_output for result in results]

    emails = "Cold sales emails: \n\n".join(outputs)

    best = await Runner.run(sales_picker, emails)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Your SOC 2 Compliance Is About to Get a Giggle Upgrade! 😂
#
# Hi [Recipient's Name],
#
# I hope this email finds you well (and maybe even a little amused)!
#
# Are you tired of tripping over the endless requirements of SOC 2 compliance? It’s like trying to solve a Rubik's cube blindfolded, isn’t it? But fear not! ComplAI is here to turn that compliance nightmare into a sweet dream. 🌙✨
#
# Imagine having a trusty teammate powered by AI that not only simplifies the process but also keeps you organized and audit-ready—like a personal assistant who never forgets coffee runs.
#
# Here’s what ComplAI brings to the (auditing) table:
# - **Streamlined Compliance**: Say goodbye to confusion. Our tool sorts through the chaos, helping you tick every box! ✅
# - **24/7 Readiness**: Get ready for audits faster than your last-moment scramble for socks on laundry day. 🧦
# - **Built-in Humor**: Okay, we can’t promise laughter, but our smart suggestions might just make the process a bit more bearable. 😉
#
# Let’s schedule a quick 15-minute call! I’ll share how we can turn compliance into a breeze—possibly even fun (but we’ll let you be the judge of that!).
#
# Looking forward to a chat that's more exciting than watching paint dry!
#
# Best,
# [Your Name]
# [Your Title]
# ComplAI
# [Your Phone Number]
# [Your LinkedIn Profile] (Optional)
#
# P.S. If you'd rather dive straight into a demo, just let me know! I promise our tool is more entertaining than scrolling through cat memes… at least most days! 🐱✨

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: use of tools
#
# Now we will add a tool to the mix.
#
# Remember all that json boilerplate and the `handle_tool_calls()` function with the if logic..

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini",
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini",
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini",
)

# %%
sales_agent1
# Out:
# Agent(name='Professional Sales Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
print(os.getenv("GMAIL_TO"))
# Out:
# jeweaver@gmail.com

# %% [markdown]
# ## Steps 2 and 3: Tools and Agent interactions
#
# Remember all that boilerplate json?
#
# Simply wrap your function with the decorator `@function_tool`

# %%
to_email = os.getenv("GMAIL_TO")

# %%
@function_tool
def send_email(body: str):
    """ Send out an email with the given body to all sales prospects via Resend """
    
    # Set up email sender, recipient, and content
    from_email = "onboarding@resend.dev" # Replace with your verified sender
    to_email = os.getenv("GMAIL_TO")  # Replace with recipient's email
    
    # Resend API headers and payload
    headers = {
        "Authorization": f"Bearer {RESEND_API_KEY}",
        "Content-Type": "application/json"
    }
    
    payload = {
        "from": f"Harsh Patidar <{from_email}>",
        "to": [to_email],
        "subject": "Sales email",
        "html": f"<p>{body}</p>"  # Body wrapped in <p> tags for HTML format
    }
    
    # Send email using Resend API
    response = requests.post("https://api.resend.com/emails", json=payload, headers=headers)
    
    # Check if the request was successful
    if response.status_code == 202:
        return {"status": "success"}
    else:
        return {"status": "failure", "message": response.text}

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
# Let's look at it
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects via Resend', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x112252f20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### And you can also convert an Agent into a tool

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x1124a59e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
description = "Write a cold sales email"

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

tools = [tool1, tool2, tool3, send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x112252a20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x1124a62a0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x1124a5080>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects via Resend', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x112252f20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
# Improved instructions thanks to student Guillermo F.

instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gpt-4o-mini")

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message)

# %%
print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Sales Manager", ...)
# - Final output (str):
#     It seems there was an issue when attempting to send the email. Unfortunately, I can't determine the exact reason from the provided information.
#
#     If you would like, I can revise the email or try sending it again. Just let me know how you'd like to proceed!
# - 10 new item(s)
# - 3 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %%
resend.api_key = os.environ["RESEND_API_KEY"]

params: resend.Emails.SendParams = {
    "from": "Acme <onboarding@resend.dev>",
    "to": ["jeweaver@gmail.com"],
    "subject": "hello world",
    "html": "<strong>it works!</strong>",
}

email = resend.Emails.send(params)
print(email)
# Out:
# {'id': '586bdd4f-ef0f-4ae3-85b0-6e63d2d09afa'}

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Wait - you didn't get an email??</h2>
#             <span style="color:#ff7800;">With much thanks to student Chris S. for describing his issue and fixes.
#             If you don't receive an email after running the prior cell, here are some things to check: <br/>
#             First, check your Spam folder! Several students have missed that the emails arrived in Spam!<br/>Second, print(result) and see if you are receiving errors about SSL.
#             If you're receiving SSL errors, then please check out theses <a href="https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d">networking tips</a> and see the note in the next cell. Also look at the trace in OpenAI, and investigate on the SendGrid website, to hunt for clues. Let me know if I can help!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# With handoffs, control passes across

# %%
subject_instructions = "You can write a subject for a cold sales email. \
You are given a message and you need to write a subject for an email that is likely to get a response."

html_instructions = "You can convert a text email body to an HTML email body. \
You are given a text email body which might have some markdown \
and you need to convert it to an HTML email body with simple, clear, compelling layout and design."

subject_writer = Agent(name="Email subject writer", instructions=subject_instructions, model="gpt-4o-mini")
subject_tool = subject_writer.as_tool(tool_name="subject_writer", tool_description="Write a subject for a cold sales email")

html_converter = Agent(name="HTML email body converter", instructions=html_instructions, model="gpt-4o-mini")
html_tool = html_converter.as_tool(tool_name="html_converter",tool_description="Convert a text email body to an HTML email body")

# %%
from urllib import response
from httpx import Headers


@function_tool
def send_html_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body to all sales prospects using Resend """
    
    from_email = "onboarding@resend.dev"
    to_email = os.getenv("GMAIL_TO")

    RESEND_API_KEY = os.getenv("RESEND_API_KEY")

    headers = {
        "Authorization": f"Bearer {RESEND_API_KEY}",
        "Content-Type": "application/json"
    }

    payload = {
        "from": f"Harsh Patidar <{from_email}>",
        "to": [to_email],
        "subject": subject,
        "html": html_body
    }

    response = requests.post("https://api.resend.com/emails", json=payload, headers=headers)
    
    if response.status_code == 202:
        return {"status": "success"}
    else:
        return {"status": "failure", "message": response.text}

# %%
tools = [subject_tool, html_tool, send_html_email]

# %%
tools

# %%
instructions ="You are an email formatter and sender. You receive the body of an email to be sent. \
You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. \
Finally, you use the send_html_email tool to send the email with the subject and HTML body."


emailer_agent = Agent(
    name="Email Manager",
    instructions=instructions,
    tools=tools,
    model="gpt-4o-mini",
    handoff_description="Convert an email to HTML and send it")

# %% [markdown]
# ### Now we have 3 tools and 1 handoff

# %%
tools = [tool1, tool2, tool3]
handoffs = [emailer_agent]
print(tools)
print(handoffs)

# %%
# Improved instructions thanks to student Guillermo F.

sales_manager_instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
You can use the tools multiple times if you're not satisfied with the results from the first try.
 
3. Handoff for Sending: Pass ONLY the winning email draft to the 'Email Manager' agent. The Email Manager will take care of formatting and sending.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must hand off exactly ONE email to the Email Manager — never more than one.
"""


sales_manager = Agent(
    name="Sales Manager",
    instructions=sales_manager_instructions,
    tools=tools,
    handoffs=handoffs,
    model="gpt-4o-mini")

message = "Send out a cold sales email addressed to Dear CEO from Alice"

with trace("Automated SDR"):
    result = await Runner.run(sales_manager, message)

# %%
print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Sales Manager", ...)
# - Final output (str):
#     It seems there was an error while trying to send the email due to an API key issue. Unfortunately, I cannot send the email directly.
#
#     You can copy the content of the selected email draft:
#
#     ---
#
#     **Subject: Streamline SOC2 Compliance with AI-Driven Solutions**
#
#     Dear CEO,
#
#     I hope this message finds you well.
#
#     At ComplAI, we understand the complexities of SOC2 compliance and the challenges that come with preparing for audits. Our AI-powered SaaS tool is designed to streamline these processes, helping businesses like yours not only meet compliance requirements but also enhance operational efficiency.
#
#     I would appreciate the opportunity to discuss how we can support your organization's strategic goals in this area. Would you be available for a brief call next week?
#
#     Best regards,
#
#     [Your Name]
#     [Your Position]
#     ComplAI
#     [Your Phone Number]
#     [Your Email Address]
#
#     ---
#
#     Feel free to replace placeholders with your details and send it via your email service. Let me know if you need further assistance!
# - 10 new item(s)
# - 3 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Can you identify the Agentic design patterns that were used here?<br/>
#             What is the 1 line that changed this from being an Agentic "workflow" to "agent" under Anthropic's definition?<br/>
#             Try adding in more tools and Agents! You could have tools that handle the mail merge to send to a list.<br/><br/>
#             HARD CHALLENGE: research how you can have SendGrid call a Callback webhook when a user replies to an email,
#             Then have the SDR respond to keep the conversation going! This may require some "vibe coding" 😂
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Extra note:
#
# Google has released their Agent Development Kit (ADK). It's not yet got the traction of the other frameworks on this course, but it's getting some attention. It's interesting to note that it looks quite similar to OpenAI Agents SDK. To give you a preview, here's a peak at sample code from ADK:
#
# ```
# root_agent = Agent(
#     name="weather_time_agent",
#     model="gemini-2.0-flash",
#     description="Agent to answer questions about the time and weather in a city.",
#     instruction="You are a helpful agent who can answer user questions about the time and weather in a city.",
#     tools=[get_weather, get_current_time]
# )
# ```
#
# Well, that looks familiar!
#
# And a student has contributed a customer care agent in community_contributions that uses ADK.
